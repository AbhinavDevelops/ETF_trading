# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [18, 7]

# %%
vgt_df = pd.read_csv("../data/VGT.csv")
vgt_df['mid'] = (vgt_df['high'] + vgt_df['low']) / 2

aapl_df = pd.read_csv("../data/AAPL.csv")
aapl_df['mid'] = (aapl_df['high'] + aapl_df['low']) / 2

msft_df = pd.read_csv("../data/MSFT.csv")
msft_df['mid'] = (msft_df['high'] + msft_df['low']) / 2

nvda_df = pd.read_csv("../data/NVDA.csv")
nvda_df['mid'] = (nvda_df['high'] + nvda_df['low']) / 2

v_df = pd.read_csv("../data/V.csv")
v_df['mid'] = (v_df['high'] + v_df['low']) / 2

fair_mid = 0.2276 * aapl_df['mid'] + 0.1804 * msft_df['mid'] + 0.0610 * nvda_df['mid'] + 0.0305 * v_df['mid']

actual_mid = 0.4995 * vgt_df['mid']

vgt_df.head()
# Out:
#                   time        open        high         low       close  \
# 0  2021-04-09 09:31:00  371.345546  371.424273  371.207774  371.424273
# 1  2021-04-09 09:32:00  371.001115  371.001115  370.725571  370.725571
# 2  2021-04-09 09:33:00  371.036346  371.036346  370.852649  370.852649
# 3  2021-04-09 09:34:00  371.071576  371.071576  370.979728  370.979728
# 4  2021-04-09 09:35:00  371.106806  371.106806  371.106806  371.106806
#
#          volume         mid
# 0  32858.000000  371.316023
# 1   3373.000000  370.863343
# 2   2384.666667  370.944497
# 3   1396.333333  371.025652
# 4    408.000000  371.106806

# %%
actual_mid
# Out:
# 0         185.472354
# 1         185.246240
# 2         185.286776
# 3         185.327313
# 4         185.367850
#              ...
# 431425    159.570138
# 431426    159.548206
# 431427    159.509051
# 431428    159.434306
# 431429    159.362029
# Name: mid, Length: 431430, dtype: float64

# %%
actual_mid.plot()
fair_mid.plot()
# Out:
# <Axes: >

# %%
22.76 + 18.04 + 6.10 + 3.05
# Out:
# 49.949999999999996
